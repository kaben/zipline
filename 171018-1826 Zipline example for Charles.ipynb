# %% [markdown]
# # 171017-1358 zipline

# %% [markdown]
# I don't recall whether this is still needed. -- KGN

# %%
# !pip install matplotlib

# %%
# %pylab inline
# %load_ext zipline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %% [markdown]
# ### Command to download backtesting data.

# %%
# !zipline clean

# %%
# !zipline ingest
# Out:
# ...
# Writing data to /root/.zipline/data/quantopian-quandl/2017-10-18T22;13;30.735025.

# %% [markdown]
# ### Basic example of defining and running a Zipline algorithm in an IPython notebook.

# %%
# %%zipline --start 2016-12-31 --end 2017-10-1
#
# from zipline.api import symbol, order, record
#
# def initialize(context):
#     pass
#
# def handle_data(context, data):
#     order(symbol('AAPL'), 10)
#     record(AAPL=data[symbol('AAPL')].price)
# Out:
#                               AAPL  algo_volatility  algorithm_period_return  \
# 2017-01-03 21:00:00+00:00  116.150              NaN             0.000000e+00
# 2017-01-04 21:00:00+00:00  116.020     1.122497e-08            -1.000000e-09
# 2017-01-05 21:00:00+00:00  116.610     5.402863e-06             5.880000e-07
# 2017-01-06 21:00:00+00:00  117.910     1.957672e-05             3.187000e-06
# 2017-01-09 21:00:00+00:00  118.990     2.424971e-05             6.426000e-06
# 2017-01-10 21:00:00+00:00  119.110     2.231002e-05             6.905000e-06
# 2017-01-11 21:00:00+00:00  119.750     2.378650e-05             1.010400e-05
# 2017-01-12 21:00:00+00:00  119.250     3.327427e-05             7.103000e-06
# 2017-01-13 21:00:00+00:00  119.040     3.353474e-05             5.632000e-06
# 2017-01-17 21:00:00+00:00  120.000     4.746850e-05             1.331100e-05
# 2017-01-18 21:00:00+00:00  119.990     4.554407e-05             1.322000e-05
# ...

# %% [markdown]
# #### A more interesting example.

# %%
# %%zipline --start 2001-1-2 --end 2012-1-1 -o dma.pickle
#
# import matplotlib.pyplot as plt
# from zipline.api import order_target, record, symbol
#
# def initialize(context):
#     context.i = 0
#     context.asset = symbol('AAPL')
#
#
# def handle_data(context, data):
#     # Skip first 300 days to get full windows
#     context.i += 1
#     if context.i < 300:
#         return
#
#     # Compute averages
#     # data.history() has to be called with the same params
#     # from above and returns a pandas dataframe.
#     short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()
#
#     # Trading logic
#     if short_mavg > long_mavg:
#         # order_target orders as many shares as needed to
#         # achieve the desired number of shares.
#         order_target(context.asset, 100)
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     # Save values for later inspection
#     record(AAPL=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
#
#
# def analyze(context, perf):
#     fig = plt.figure()
#     ax1 = fig.add_subplot(211)
#     perf.portfolio_value.plot(ax=ax1)
#     ax1.set_ylabel('portfolio value in $')
#
#     ax2 = fig.add_subplot(212)
#     perf['AAPL'].plot(ax=ax2)
#     perf[['short_mavg', 'long_mavg']].plot(ax=ax2)
#
#     perf_trans = perf.ix[[t != [] for t in perf.transactions]]
#     buys = perf_trans.ix[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
#     sells = perf_trans.ix[
#         [t[0]['amount'] < 0 for t in perf_trans.transactions]]
#     ax2.plot(buys.index, perf.short_mavg.ix[buys.index],
#              '^', markersize=10, color='m')
#     ax2.plot(sells.index, perf.short_mavg.ix[sells.index],
#              'v', markersize=10, color='k')
#     ax2.set_ylabel('price in $')
#     plt.legend(loc=0)
#     plt.show()
# Out:
#                               AAPL  algo_volatility  algorithm_period_return  \
# 2001-01-02 21:00:00+00:00      NaN              NaN                 0.000000
# 2001-01-03 21:00:00+00:00      NaN         0.000000                 0.000000
# 2001-01-04 21:00:00+00:00      NaN         0.000000                 0.000000
# 2001-01-05 21:00:00+00:00      NaN         0.000000                 0.000000
# 2001-01-08 21:00:00+00:00      NaN         0.000000                 0.000000
# 2001-01-09 21:00:00+00:00      NaN         0.000000                 0.000000
# 2001-01-10 21:00:00+00:00      NaN         0.000000                 0.000000
# 2001-01-11 21:00:00+00:00      NaN         0.000000                 0.000000
# 2001-01-12 21:00:00+00:00      NaN         0.000000                 0.000000
# 2001-01-16 21:00:00+00:00      NaN         0.000000                 0.000000
# 2001-01-17 21:00:00+00:00      NaN         0.000000                 0.000000
# ...
